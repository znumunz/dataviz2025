# %% [markdown]
# <a href="https://colab.research.google.com/github/znumunz/dataviz2025/blob/main/Data_Viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Viz

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

iris_df['target'] = iris.targetำ

display(iris_df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_bunch.py in __getattr__(self, key)
#      56         try:
# ---> 57             return self[key]
#      58         except KeyError:
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_bunch.py in __getitem__(self, key)
#      41             )
# ---> 42         return super().__getitem__(key)
#      43
#
# KeyError: 'targetํา'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2393299735.py in <cell line: 0>()
#       5 iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
#       6
# ----> 7 iris_df['target'] = iris.targetำ
#       8
#       9 display(iris_df.head())
#
# ...

# %%
import matplotlib

# %%
from matplotlib import pyplot as plt

# %%
matplotlib.rcParams['figure.figsize'] = (30.0, 30.0)
plt.imshow(iris_df.iloc[:,:])
plt.show()

# %% [markdown]
# ## pnadas : paralell coordinate

# %%
iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

iris_df['target'] = iris.target

display(iris_df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
matplotlib.rcParams['figure.figsize'] = (8.0, 8.0)
pd.plotting.parallel_coordinates(iris_df, 'target')
# Out:
# <Axes: >

# %%
pd.plotting.scatter_matrix(iris_df, figsize=(5, 5))
# Out:
# array([[<Axes: xlabel='sepal length (cm)', ylabel='sepal length (cm)'>,
#         <Axes: xlabel='sepal width (cm)', ylabel='sepal length (cm)'>,
#         <Axes: xlabel='petal length (cm)', ylabel='sepal length (cm)'>,
#         <Axes: xlabel='petal width (cm)', ylabel='sepal length (cm)'>,
#         <Axes: xlabel='target', ylabel='sepal length (cm)'>],
#        [<Axes: xlabel='sepal length (cm)', ylabel='sepal width (cm)'>,
#         <Axes: xlabel='sepal width (cm)', ylabel='sepal width (cm)'>,
#         <Axes: xlabel='petal length (cm)', ylabel='sepal width (cm)'>,
#         <Axes: xlabel='petal width (cm)', ylabel='sepal width (cm)'>,
#         <Axes: xlabel='target', ylabel='sepal width (cm)'>],
#        [<Axes: xlabel='sepal length (cm)', ylabel='petal length (cm)'>,
#         <Axes: xlabel='sepal width (cm)', ylabel='petal length (cm)'>,
#         <Axes: xlabel='petal length (cm)', ylabel='petal length (cm)'>,
# ...

# %% [markdown]
# #3 Data

# %%
df1 = pd.read_csv("/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-01/2025-01-city-of-london-outcomes.csv")
df2 = pd.read_csv("/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-02/2025-02-city-of-london-outcomes.csv")
df3 = pd.read_csv("/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-03/2025-03-city-of-london-outcomes.csv")

# %% [markdown]
# ## color

# %%
matplotlib.rcParams['figure.figsize'] = (30.0, 30.0)
plt.imshow(iris_df.iloc[:,:],interpolation= 'nearest',cmap = 'rainbow')

# %% [markdown]
# ## color code

# %%
matplotlib.rcParams['figure.figsize'] = (8.0, 8.0)
pd.plotting.parallel_coordinates(iris_df, 'target',color = ['c','m','k'])
# Out:
# <Axes: >

# %%
matplotlib.rcParams['figure.figsize'] = (8.0, 8.0)
pd.plotting.parallel_coordinates(iris_df, 'target',color = [[1,0,0.3],[0.3,0.8,1],[0.4,1,0.7]])
# Out:
# <Axes: >

# %% [markdown]
# ## HTML Color

# %%
matplotlib.rcParams['figure.figsize'] = (8.0, 8.0)
pd.plotting.parallel_coordinates(iris_df, 'target',color = ['#375878','#783760','#D4C600'])
# Out:
# <Axes: >
