# %% [markdown]
# <a href="https://colab.research.google.com/github/znumunz/dataviz2025/blob/main/Copy_of_Visualize_Data_Comparison_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
#from datetime import datetime as dt
from datetime import time
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path1 = '/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-01/2025-01-bedfordshire-stop-and-search.csv'
path2 = '/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-02/2025-02-bedfordshire-stop-and-search.csv'
path3= '/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-03/2025-03-bedfordshire-stop-and-search.csv'
path4 = '/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-04/2025-04-bedfordshire-stop-and-search.csv'

# %%
df1 = pd.read_csv(path1)
df2 = pd.read_csv(path2)
df3 = pd.read_csv(path3)
df4 = pd.read_csv(path4)

# %%
df = pd.read_csv(path)
df.head()
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude  Gender Age range  \
# 0                 NaN  51.881481   -0.41311    Male     25-34
# 1                 NaN  52.132059   -0.29660    Male     10-17
# 2                 NaN  52.132059   -0.29660    Male     10-17
# 3                 NaN  52.132059   -0.29660  Female     10-17
# 4                 NaN  52.132059   -0.29660    Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# ...

# %% [markdown]
# ## Quiz 12  สร้างตารางที่แสดงจำนวนเคสที่ตำรวจเป็นเชื้อชาติที่จับโดยตำรวจเชื้อชาติต่างๆ

# %%
cross_tab = pd.crosstab(df1['Officer-defined ethnicity'], df1['Self-defined ethnicity'])
cross_tab_sorted = cross_tab.sum(axis=1).sort_values(ascending=True)
display(cross_tab_sorted)
# Out:
# Officer-defined ethnicity
# Other      9
# Black     63
# Asian     79
# White    191
# dtype: int64

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=bar)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-926949552.py in <cell line: 0>()
#       1 from google.colab import sheets
# ----> 2 sheet = sheets.InteractiveSheet(df=bar)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/sheets.py in __init__(self, title, url, sheet_id, df, worksheet_id, worksheet_name, credentials, include_column_headers, display, backend)
#     147       url = f'https://docs.google.com/spreadsheets/d/{sheet_id}'
#     148     self._credentials = credentials
# --> 149     self._ensure_gspread_client()
#     150
#     151     self.sheet = self._load_or_create_sheet(url, title)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/sheets.py in _ensure_gspread_client(self)
#     217     global _gspread_client
#     218     if _gspread_client is None:
# --> 219       creds = InteractiveSheet.generate_creds(self._credentials)
# ...

# %%
plt.bar(bar['Officer-defined ethnicity'],bar['count'],color = ['yellow','brown','red','blue'])
plt.xlabel('Officer-defined ethnicity')
plt.ylabel('count')
plt.title('Number of Cases open by different ethnicity')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-25139002.py in <cell line: 0>()
# ----> 1 plt.bar(bar['Officer-defined ethnicity'],bar['count'],color = ['yellow','brown','red','blue'])
#       2 plt.xlabel('Officer-defined ethnicity')
#       3 plt.ylabel('count')
#       4 plt.title('Number of Cases open by different ethnicity')
#       5 plt.show()
#
# NameError: name 'bar' is not defined

# %%
# Out:
#      Year Quarter         Region   Brand Price Category  Sales
# 0    2021      Q1  North America  BrandA    รุ่นประหยัด   8270
# 1    2021      Q1  North America  BrandA   รุ่นเริ่มต้น   1860
# 2    2021      Q1  North America  BrandA     รุ่นเรือธง   6390
# 3    2021      Q1  North America  BrandB    รุ่นประหยัด   6191
# 4    2021      Q1  North America  BrandB   รุ่นเริ่มต้น   6734
# ..    ...     ...            ...     ...            ...    ...
# 475  2022      Q4         Africa  BrandC   รุ่นเริ่มต้น   6486
# 476  2022      Q4         Africa  BrandC     รุ่นเรือธง   9335
# 477  2022      Q4         Africa  BrandD    รุ่นประหยัด   5980
# 478  2022      Q4         Africa  BrandD   รุ่นเริ่มต้น   8266
# 479  2022      Q4         Africa  BrandD     รุ่นเรือธง   5491
#
# [480 rows x 6 columns]

# %% [markdown]
# ## Bar chart (กราฟแท่ง) (กราฟผลไม้)

# %%
# prompt: สร้าง bar chart เปรียบเทียบปริมาณ sales ทั้งหมดของแต่ละ region ด้วยคำสั้ง plt.bar

import matplotlib.pyplot as plt

# Group data by region and sum sales
region_sales = data.groupby('Region')['Sales'].sum()

# Create the bar chart
plt.bar(region_sales.index, region_sales.values)

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2037252087.py in <cell line: 0>()
#       4
#       5 # Group data by region and sum sales
# ----> 6 region_sales = data.groupby('Region')['Sales'].sum()
#       7
#       8 # Create the bar chart
#
# NameError: name 'data' is not defined

# %%
region_sales
# Out:
# Region
# Africa           541556
# Asia             519608
# Europe           548068
# North America    545563
# South America    529246
# Name: Sales, dtype: int64

# %%
region_sales.reset_index()['Region']
# Out:
# 0           Africa
# 1             Asia
# 2           Europe
# 3    North America
# 4    South America
# Name: Region, dtype: object

# %%
region_sales.reset_index().Region
# Out:
# 0           Africa
# 1             Asia
# 2           Europe
# 3    North America
# 4    South America
# Name: Region, dtype: object

# %%
region_sales.values
# Out:
# array([541556, 519608, 548068, 545563, 529246])

# %%
region_sales.index
# Out:
# Index(['Africa', 'Asia', 'Europe', 'North America', 'South America'], dtype='object', name='Region')

# %%
# Group data by region and sum sales
data = df.groupby(['Officer-defined ethnicity','Age range'])['Type'].count()
data
# Out:
# Officer-defined ethnicity  Age range
# Asian                      10-17         9
#                            18-24        28
#                            25-34        23
#                            over 34      17
# Black                      10-17         8
#                            18-24        21
#                            25-34        10
#                            over 34      23
# Other                      18-24         1
#                            25-34         4
#                            over 34       4
# White                      10-17        25
#                            18-24        47
#                            25-34        38
#                            over 34      78
#                            under 10      1
# Name: Type, dtype: int64

# %%
df1.groupby('Officer-defined ethnicity')['Type'].count().reset_index().sort_values(by='Type')
# Out:
#   Officer-defined ethnicity  Type
# 2                     Other     9
# 1                     Black    64
# 0                     Asian    81
# 3                     White   199

# %%
compare1 = df1.groupby('Officer-defined ethnicity')['Type'].count().reset_index().sort_values(by='Type')
compare2 = df2.groupby('Officer-defined ethnicity')['Type'].count().reset_index().sort_values(by='Type')
compare3 = df3.groupby('Officer-defined ethnicity')['Type'].count().reset_index().sort_values(by='Type')
compare4 = df4.groupby('Officer-defined ethnicity')['Type'].count().reset_index().sort_values(by='Type')

# %%
plt.bar(compare1['Officer-defined ethnicity'],compare1['Type'],
        color = [[249/255,249/255,0/255,0.4],[107/255,107/255,0/255,0.4],[107/255,107/255,107/255,0.4],[250/255,117/255,117/255,0.4]]
        ,label = 'Jan')
plt.bar(compare2['Officer-defined ethnicity'],compare2['Type'],
        bottom= compare1['Type'],
        color =[[249/255,249/255,0/255,0.7],[107/255,107/255,0/255,0.7],[107/255,107/255,107/255,0.7],[250/255,117/255,117/255,0.7]]
        ,label = 'Feb')
plt.bar(compare3['Officer-defined ethnicity'],compare3['Type'],
        bottom= compare1['Type'] + compare2['Type'],
        color =[[249/255,249/255,0/255,0.9],[107/255,107/255,0/255,0.9],[107/255,107/255,107/255,0.9],[250/255,117/255,117/255,0.9]]
        ,label = 'march')
plt.bar(compare4['Officer-defined ethnicity'],compare4['Type'],
        bottom= compare1['Type'] + compare2['Type'] + + compare3['Type'],
        color =[[249/255,249/255,0/255],[107/255,107/255,0/255],[107/255,107/255,107/255],[250/255,117/255,117/255]]
        ,label = 'april')

plt.xlabel('Officer-defined ethnicity')
plt.ylabel('count')
plt.title('Number of Cases open by different ethnicity')
plt.show()

# %%
compare1 = df1.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compare2 = df2.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compare3 = df3.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compare4 = df4.groupby('Officer-defined ethnicity')['Type'].count().reset_index()

# %%
plt.bar(compare1['Officer-defined ethnicity'],compare1['Type'],
        color = [[249/255,249/255,0/255,0.4],[107/255,107/255,0/255,0.4],[107/255,107/255,107/255,0.4],[250/255,117/255,117/255,0.4]]
        ,label = 'Jan')
plt.bar(compare2['Officer-defined ethnicity'],compare2['Type'],
        bottom= compare1['Type'],
        color =[[249/255,249/255,0/255,0.7],[107/255,107/255,0/255,0.7],[107/255,107/255,107/255,0.7],[250/255,117/255,117/255,0.7]]
        ,label = 'Feb')
plt.bar(compare3['Officer-defined ethnicity'],compare3['Type'],
        bottom= compare1['Type'] + compare2['Type'],
        color =[[249/255,249/255,0/255,0.9],[107/255,107/255,0/255,0.9],[107/255,107/255,107/255,0.9],[250/255,117/255,117/255,0.9]]
        ,label = 'march')
plt.bar(compare4['Officer-defined ethnicity'],compare4['Type'],
        bottom= compare1['Type'] + compare2['Type'] + + compare3['Type'],
        color =[[249/255,249/255,0/255],[107/255,107/255,0/255],[107/255,107/255,107/255],[250/255,117/255,117/255]]
        ,label = 'april')

plt.xlabel('Officer-defined ethnicity')
plt.ylabel('count')
plt.title('Number of Cases open by different ethnicity')
plt.legend()
plt.show()

# %%
# Calculate total count for each ethnicity across all months
total_counts = compare1.set_index('Officer-defined ethnicity')['Type'] + \
               compare2.set_index('Officer-defined ethnicity')['Type'] + \
               compare3.set_index('Officer-defined ethnicity')['Type'] + \
               compare4.set_index('Officer-defined ethnicity')['Type']

# Sort the ethnicities based on total count
sorted_ethnicities = total_counts.sort_values().index

# Reindex the dataframes according to the sorted ethnicities
compare1_sorted = compare1.set_index('Officer-defined ethnicity').reindex(sorted_ethnicities).reset_index()
compare2_sorted = compare2.set_index('Officer-defined ethnicity').reindex(sorted_ethnicities).reset_index()
compare3_sorted = compare3.set_index('Officer-defined ethnicity').reindex(sorted_ethnicities).reset_index()
compare4_sorted = compare4.set_index('Officer-defined ethnicity').reindex(sorted_ethnicities).reset_index()

# Define the requested colors in the specified order
colors = [[128/255,128/255,128/255], [249/255,249/255,0/255], [107/255,107/255,0/255], [255/255, 192/255, 203/255]] # Grey, Yellow, Brown, Pink

# Plot the stacked bar chart with sorted data and specified colors
plt.bar(compare1_sorted['Officer-defined ethnicity'], compare1_sorted['Type'],
        color=[colors[i] + [0.2] for i in range(len(colors))],
        label = 'Jan')
plt.bar(compare2_sorted['Officer-defined ethnicity'], compare2_sorted['Type'],
        bottom= compare1_sorted['Type'],
        color=[colors[i] + [0.6] for i in range(len(colors))],
        label = 'Feb')
plt.bar(compare3_sorted['Officer-defined ethnicity'], compare3_sorted['Type'],
        bottom= compare1_sorted['Type'] + compare2_sorted['Type'],
        color=[colors[i] + [0.9] for i in range(len(colors))],
        label = 'march')
plt.bar(compare4_sorted['Officer-defined ethnicity'], compare4_sorted['Type'],
        bottom= compare1_sorted['Type'] + compare2_sorted['Type'] + compare3_sorted['Type'],
        color=colors,
        label = 'april')

plt.xlabel('Officer-defined ethnicity')
plt.ylabel('count')
plt.title('Number of Cases open by different ethnicity')
plt.legend()
plt.show()

# %%
# prompt: สร้าง bar chart เปรียบเทียบปริมาณ sales ทั้งหมดในแต่ละ quarter ของแต่ละ region ด้วย stacked barchart

import matplotlib.pyplot as plt
# Group data by region and quarter, then sum sales
region_quarter_sales = data.groupby(['Region', 'Quarter'])['Sales'].sum().unstack()

# Create the stacked bar chart
region_quarter_sales.plot(kind='bar', stacked=True)

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region and Quarter')

# Show the plot
plt.show()

# %% [markdown]
# ## plot stacked barchart ของแต่ละ region โดยดูจาก contribution ของ Price Category

# %%
# prompt: plot stacked barchart ของแต่ละ region โดยดูจาก contribution ของ Price Category

import matplotlib.pyplot as plt
# Group data by region and price category, then sum sales
region_price_category_sales = data.groupby(['Region', 'Price Category'])['Sales'].sum().unstack()

# Create the stacked bar chart
region_price_category_sales.plot(kind='bar', stacked=True)

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region and Price Category')

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3640 (\N{THAI CHARACTER SARA U}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3656 (\N{THAI CHARACTER MAI EK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# การแสดงตัวอักษรภาษาไทยในกราฟ matplotlib
# https://medium.com/@kanyawee.work/%E0%B9%81%E0%B8%AA%E0%B8%94%E0%B8%87%E0%B8%9C%E0%B8%A5%E0%B8%A0%E0%B8%B2%E0%B8%A9%E0%B8%B2%E0%B9%84%E0%B8%97%E0%B8%A2%E0%B9%83%E0%B8%99%E0%B8%81%E0%B8%A3%E0%B8%B2%E0%B8%9F%E0%B8%82%E0%B8%AD%E0%B8%87-matplotlib-%E0%B8%9A%E0%B8%99-google-colab-37210d9a9f31
#
#
# https://colab.research.google.com/drive/1sTdTZx_Cm51mc8OL_QHtehWyO4725sGl#scrollTo=Ak9SbVd5L7U8

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
# prompt: plot stacked barchart ของแต่ละ region โดยดูจาก contribution ของ Price Category

import matplotlib.pyplot as plt
# Group data by region and price category, then sum sales
region_price_category_sales = data.groupby(['Region', 'Price Category'])['Sales'].sum().unstack()

# Create the stacked bar chart
region_price_category_sales.plot(kind='bar', stacked=True)

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region and Price Category')

# Show the plot
plt.show()

# %% [markdown]
# ## Plot stacked barchart ด้วย matplotlib

# %%
region_brand_sales = data.groupby(['Region', 'Brand'])['Sales'].sum().unstack()
region_brand_sales
# Out:
# Brand          BrandA  BrandB  BrandC  BrandD
# Region
# Africa         132019  140187  132273  137077
# Asia           136205  124678  139677  119048
# Europe         135638  135069  131700  145661
# North America  124810  153135  140802  126816
# South America  144169  138543  115774  130760

# %%
region_brand_sales['BrandA'].values
# Out:
# array([132019, 136205, 135638, 124810, 144169])

# %%
region_brand_sales.index
# Out:
# Index(['Africa', 'Asia', 'Europe', 'North America', 'South America'], dtype='object', name='Region')

# %% [markdown]
# ## plot ส่วนแรก

# %%
import matplotlib.pyplot as plt

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(region_brand_sales.index, region_brand_sales['BrandA'].values, width, label='BrandA',color = '#fc9700')
#ax.bar(labels, b4midnight, width, bottom=b4lunch, label='before midnight',color = '#19038a')

ax.set_ylabel('Total sales')
ax.set_xlabel('Region')
ax.set_title('Total sales by region and brand')
ax.legend()

plt.show()

# %% [markdown]
# ## plot ส่วนที่ 2

# %%
import matplotlib.pyplot as plt

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(region_brand_sales.index, region_brand_sales['BrandA'].values, width, label='BrandA',color = '#fc9700')
ax.bar(region_brand_sales.index, region_brand_sales['BrandB'].values, width, bottom=region_brand_sales['BrandA'].values, label='BrandB',color = '#19038a')

ax.set_ylabel('Total sales')
ax.set_xlabel('Region')
ax.set_title('Total sales by region and brand')
ax.legend()

plt.show()

# %% [markdown]
# ## plot ส่วนที่ 3

# %%
import matplotlib.pyplot as plt

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(region_brand_sales.index, region_brand_sales['BrandA'].values, width, label='BrandA',color = '#fc9700')
ax.bar(region_brand_sales.index, region_brand_sales['BrandB'].values, width,
       bottom=region_brand_sales['BrandA'].values, label='BrandB',color = '#19038a')
ax.bar(region_brand_sales.index, region_brand_sales['BrandC'].values, width,
       bottom=region_brand_sales['BrandA'].values + region_brand_sales['BrandB'].values, label='BrandC',color = '#FF5733')


ax.set_ylabel('Total sales')
ax.set_xlabel('Region')
ax.set_title('Total sales by region and brand')
ax.legend()

plt.show()

# %% [markdown]
# # Grouped bar chart (เปรียบเทียบในกลุ่ม)

# %%
path1 = '/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-01/2025-01-bedfordshire-stop-and-search.csv'
path2 = '/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-02/2025-02-bedfordshire-stop-and-search.csv'
path3= '/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-03/2025-03-bedfordshire-stop-and-search.csv'
path4 = '/content/drive/MyDrive/MyPython&DataViz2025/Data/2025-04/2025-04-bedfordshire-stop-and-search.csv'

# %%
df1 = pd.read_csv(path1)
df2 = pd.read_csv(path2)
df3 = pd.read_csv(path3)
df4 = pd.read_csv(path4)

# %%
import numpy as np

# %%
x = np.arange(len(compare1))
width = 0.35
fig,ax = plt.subplots()
rects1 = ax.bar(x - width/2, compare1['Type'], width, label='Jan')
rects2 = ax.bar(x + width/2, compare2['Type'], width, label='Feb')

ax.set_ylabel('count')
ax.set_title('Number of Cases open by different ethnicity')
ax.set_xticks(x)
ax.set_xticklabels(compare1['Officer-defined ethnicity'])
ax.legend()

plt.show()

# %% [markdown]
# ##quiz 13

# %%
x = np.arange(len(compare1))
width = 0.25
fig,ax = plt.subplots()
rects1 = ax.bar(x - width, compare1['Type'], width, label='Jan')
rects2 = ax.bar(x, compare2['Type'], width, label='Feb')
rects3 = ax.bar(x + width, compare3['Type'], width, label='Mar')

ax.set_ylabel('count')
ax.set_title('Number of Cases open by different ethnicity')
ax.set_xticks(x)
ax.set_xticklabels(compare1['Officer-defined ethnicity'])
ax.legend()

plt.show()

# %%
# prompt: plot grouped bar chart ของแต่ละ region ในปี 2021 เพื่อเปรียบเทียบ sales ของแต่ละ price category ย้าย legend ออกไปข้างนอกกราฟ ปรับขนาด plot ให้เล็กลง 30%

import matplotlib.pyplot as plt
# Group data by region, year, and price category, then sum sales
region_year_price_category_sales = data[data['Year'] == 2021].groupby(['Region', 'Price Category'])['Sales'].sum().unstack()

# Create the grouped bar chart
ax = region_year_price_category_sales.plot(kind='bar', figsize=(8, 6), width=0.8)

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region and Price Category in 2021')

# Move legend outside the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Adjust plot size
plt.gcf().set_size_inches(plt.gcf().get_size_inches() * 0.7)

# Show the plot
plt.show()

# %% [markdown]
# ## Plot grouped bar chart ของ หนังอินเดีย โดย แยกกลุ่มตามประเภทหนัง และเปรียบเทียบ rating จาก ความยาวของหนัง

# %%
data_india = pd.read_csv(os.path.join(path,'IMDb Movies India.csv'), encoding='latin-1')
data_india.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
data_india = data_india.dropna(subset=['Rating','Duration','Genre'])
data_india = data_india[['Rating','Duration','Genre']]
data_india
# Out:
#        Rating Duration                      Genre
# 1         7.0  109 min                      Drama
# 3         4.4  110 min            Comedy, Romance
# 5         4.7  147 min     Comedy, Drama, Musical
# 6         7.4  142 min        Drama, Romance, War
# 8         5.6   82 min  Horror, Mystery, Thriller
# ...       ...      ...                        ...
# 15493     6.1  115 min                      Drama
# 15494     6.2  153 min  Biography, Drama, History
# 15503     5.8  125 min       Action, Crime, Drama
# 15505     4.5  129 min              Action, Drama
# 15508     6.2  130 min              Action, Drama
#
# [5820 rows x 3 columns]

# %%
# prompt: แปลงค่าใน column duration เป็น int โดยลบ min ออกและ เปลี่ยนชนิดข้อมูลเป็น integer

# Remove " min" from the 'Duration' column and convert to integer
data_india['Duration'] = data_india['Duration'].str.replace(' min', '').astype(int)

# %%
data_india.describe()
# Out:
#             Rating     Duration
# count  5820.000000  5820.000000
# mean      5.929450   132.255155
# std       1.391797    26.557936
# min       1.100000    21.000000
# 25%       5.000000   117.000000
# 50%       6.100000   134.000000
# 75%       7.000000   150.000000
# max      10.000000   321.000000

# %%
# prompt: แยกตารางออกเป็นตารางย่อย 5 ตารางสำหรับ genre: drama, action, romance, horror, musical

# Create a dictionary to store the tables
genre_tables = {}

# Define the genres to extract
genres = ['Drama', 'Action', 'Romance', 'Horror', 'Musical']

# Iterate through the genres and create separate tables
for genre in genres:
  genre_tables[genre] = data_india[data_india['Genre'] == genre].copy()

# Access the tables using the genre as the key
# Example:
# drama_table = genre_tables['Drama']

# %%
all_table = pd.concat(genre_tables.values())
all_table
# Out:
#        Rating  Duration    Genre
# 1         7.0       109    Drama
# 10        6.2        96    Drama
# 30        7.1       116    Drama
# 32        5.6       168    Drama
# 36        4.5        94    Drama
# ...       ...       ...      ...
# 7422      5.1       127  Musical
# 7770      4.6       119  Musical
# 10989     6.7       125  Musical
# 13934     5.9       103  Musical
# 15189     5.4       132  Musical
#
# [1256 rows x 3 columns]

# %%
# prompt: แบ่ง duration ออกเป็น short, medium, long โดย short สั้นกว่า 60 medium 60-90 ที่เหลือ เป็น long

# Function to categorize duration
def categorize_duration(duration):
  if duration < 60:
    return 'short'
  elif 60 <= duration <= 90:
    return 'medium'
  else:
    return 'long'

# Apply the function to create a new column
all_table['Duration Category'] = all_table['Duration'].apply(categorize_duration)
all_table
# Out:
#        Rating  Duration    Genre Duration Category
# 1         7.0       109    Drama              long
# 10        6.2        96    Drama              long
# 30        7.1       116    Drama              long
# 32        5.6       168    Drama              long
# 36        4.5        94    Drama              long
# ...       ...       ...      ...               ...
# 7422      5.1       127  Musical              long
# 7770      4.6       119  Musical              long
# 10989     6.7       125  Musical              long
# 13934     5.9       103  Musical              long
# 15189     5.4       132  Musical              long
#
# [1256 rows x 4 columns]

# %%
all_table.groupby(['Genre','Duration Category'])['Rating'].mean()
# Out:
# Genre    Duration Category
# Action   long                 5.086228
#          medium               4.966667
#          short                4.500000
# Drama    long                 6.404376
#          medium               6.582759
#          short                6.166667
# Horror   long                 4.622222
#          medium               4.927273
#          short                4.500000
# Musical  long                 5.122222
# Romance  long                 5.523770
#          medium               5.700000
#          short                6.300000
# Name: Rating, dtype: float64

# %%
india_bar_data = all_table.groupby(['Genre','Duration Category'])['Rating'].mean().unstack()

# %%
india_bar_data
# Out:
# Duration Category      long    medium     short
# Genre
# Action             5.086228  4.966667  4.500000
# Drama              6.404376  6.582759  6.166667
# Horror             4.622222  4.927273  4.500000
# Musical            5.122222       NaN       NaN
# Romance            5.523770  5.700000  6.300000

# %%
ax = india_bar_data.plot(kind='bar', figsize=(8, 6), width=0.8)

# Add labels and title
plt.xlabel('Genre')
plt.ylabel('Rating')
plt.title('หนังอินเดีย โดย แยกกลุ่มตามประเภทหนัง และเปรียบเทียบ rating จาก ความยาวของหนัง')

# Move legend outside the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Adjust plot size
plt.gcf().set_size_inches(plt.gcf().get_size_inches() * 0.7)

# Show the plot
plt.show()

# %%
plt.bar([1,2,3,4,5,6,7],[data[data['search_timestamp'].dt.dayofweek == 0].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 1].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 2].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 3].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 4].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 5].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 6].shape[0]
                         ],tick_label=['Mon','Tue','Wed','Thu','Fri','Sat','Sun'])
plt.xlabel('Days')
plt.ylabel('Number of Requests')
plt.title('ปริมาณคนเข้าใช้ Wongnai.com ในแต่ละวัน');

# %%
plt.bar([1,2,3,4,5,6,7],[data[data['search_timestamp'].dt.dayofweek == 0].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 1].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 2].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 3].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 4].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 5].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 6].shape[0]
                         ],tick_label=['Mon','Tue','Wed','Thu','Fri','Sat','Sun'])
plt.xlabel('Days')
plt.ylabel('Number of Requests')
# Out:
# Text(0, 0.5, 'Number of Requests')

# %% [markdown]
# ## Grouped bar chart
#
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py

# %% [markdown]
# แสดงปริมาณคนเข้าเว๊ปในแต่ละวัน โดยเปรียบเทียบช่วงเวลา 11:00-12:00 กับ 23:00-24:00

# %%
data[(data['search_timestamp'].dt.dayofweek == 0)
& (data['search_timestamp'].dt.time < time(hour=12))
& (data['search_timestamp'].dt.time >= time(hour=11))].shape[0]  # monday 11:00-12:00
# Out:
# 73249

# %%
b4lunch = [data[(data['search_timestamp'].dt.dayofweek == 0)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 1)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 2)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 3)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 4)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 5)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 6)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0]
                         ]

# %%
b4lunch
# Out:
# [73249, 73083, 75429, 78024, 99007, 174165, 165440]

# %%
data[(data['search_timestamp'].dt.dayofweek == 0)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0]
# Out:
# 31874

# %%
b4midnight = [data[(data['search_timestamp'].dt.dayofweek == 0)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 1)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 2)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 3)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 4)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 5)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 6)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0]
                         ]
b4midnight
# Out:
# [31874, 32258, 31153, 35944, 53174, 58306, 35801]

# %%
labels = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']

# %%
import numpy as np

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, b4lunch, width, label='lunch time',color = '#fc9700')
rects2 = ax.bar(x + width/2, b4midnight, width, label='midnight',color = '#19038a')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of requests')
ax.set_title('ปริมาณคนเข้าใช้ Wongnai.com ในแต่ละวัน เปรียบเทียบ 2 ช่วงเวลา')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend();

# %% [markdown]
# ## Stacked bar chart

# %%
import matplotlib.pyplot as plt

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, b4lunch, width, label='before lunch',color = '#fc9700')
ax.bar(labels, b4midnight, width, bottom=b4lunch, label='before midnight',color = '#19038a')

ax.set_ylabel('number of requests')
ax.set_title('ปริมาณคนเข้าใช้ Wongnai.com ในแต่ละวัน โดยคิดจาก 2 ช่วงเวลา')
ax.legend()

plt.show()

# %%
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.barh(labels, b4lunch, width, label='before lunch',color = '#fc9700')
ax.barh(labels, b4midnight, width, left=b4lunch, label='before midnight',color = '#19038a')

ax.set_xlabel('number of requests')
ax.set_title('ปริมาณคนเข้าใช้ Wongnai.com ในแต่ละวัน โดยคิดจาก 2 ช่วงเวลา')
ax.legend()

plt.show()

# %% [markdown]
# ## [เช็คชื่อ] โดยให้วาด Bar chart ที่เปรียบเทียบปริมาณคนใช้งาน Wongnai.com สองช่วงเวลา โดยให้กราฟแสดงสัดส่วนของปริมาณคนใช้งานในแต่ละวันด้วย

# %% [markdown]
# ## Histogram

# %% [markdown]
# ## กราฟแสดงความถี่ของข้อมูล

# %% [markdown]
# ตัวอย่างข้อมูลที่ random มาจาก normal distribution ที่มี mean = 100  และ stdev = 15

# %%
import numpy as np
from matplotlib import pyplot as plt

np.random.seed(2024)

mu, sigma = 100, 15
X = mu + sigma * np.random.randn(10000)

plt.hist(X, 50, facecolor = 'violet', alpha = 0.75)
# Out:
# (array([  2.,   2.,   2.,   4.,   9.,  14.,  17.,  39.,  47.,  59.,  90.,
#         144., 159., 202., 288., 325., 388., 430., 507., 537., 604., 642.,
#         650., 615., 590., 546., 534., 507., 429., 357., 323., 233., 196.,
#         171., 113.,  73.,  51.,  36.,  26.,  22.,   5.,   3.,   2.,   2.,
#           2.,   0.,   2.,   0.,   0.,   1.]),
#  array([ 44.90650513,  47.32901741,  49.7515297 ,  52.17404198,
#          54.59655427,  57.01906656,  59.44157884,  61.86409113,
#          64.28660341,  66.7091157 ,  69.13162798,  71.55414027,
#          73.97665256,  76.39916484,  78.82167713,  81.24418941,
#          83.6667017 ,  86.08921398,  88.51172627,  90.93423856,
#          93.35675084,  95.77926313,  98.20177541, 100.6242877 ,
#         103.04679998, 105.46931227, 107.89182456, 110.31433684,
#         112.73684913, 115.15936141, 117.5818737 , 120.00438598,
#         122.42689827, 124.84941056, 127.27192284, 129.69443513,
# ...

# %% [markdown]
# ## ทดสอบกับข้อมูลหนังอินเดีย

# %%
data_india = pd.read_csv(os.path.join(path,'IMDb Movies India.csv'), encoding='latin-1')
data_india.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
len(set(data_india.dropna(subset=['Genre'])['Genre']))
# Out:
# 485

# %%
plt.hist(data_india.dropna(subset=['Genre'])['Genre'],bins = len(set(data_india.dropna(subset=['Genre'])['Genre'])))
plt.xticks(rotation='vertical');

# %%
data_india['Genre'].str.split(',', expand=True)
# Out:
#             0         1     2
# 0       Drama      None  None
# 1       Drama      None  None
# 2       Drama   Musical  None
# 3      Comedy   Romance  None
# 4       Drama      None  None
# ...       ...       ...   ...
# 15504  Action      None  None
# 15505  Action     Drama  None
# 15506  Action      None  None
# 15507  Action      None  None
# 15508  Action     Drama  None
#
# [15509 rows x 3 columns]

# %%
data_india = data_india.dropna(subset=['Genre'])

# %%
# prompt: split value in column genre by ',' and make more column for each of those

import pandas as pd
# Split the 'Genre' column by ',' and create new columns
genre_split = data_india['Genre'].str.split(',', expand=True)

# Rename the new columns
genre_split.columns = ['Genre1', 'Genre2', 'Genre3']

# Concatenate the new columns with the original DataFrame
data_india = pd.concat([data_india, genre_split], axis=1)

# Display the updated DataFrame
data_india.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3  Genre1    Genre2 Genre3
# 0  Rajendra Bhatia   Drama      None   None
# ...

# %%
# prompt: delete space in the value in Genre1 Genre2 Genre3

for col in ['Genre1', 'Genre2', 'Genre3']:
  data_india[col] = data_india[col].str.strip() if data_india[col].dtype == 'object' else data_india[col]

# %%
allGenre = list(data_india['Genre1'])+list(data_india['Genre2'])+list(data_india['Genre3'])

# %%
len(set(allGenre))
# Out:
# 25

# %%
allGenre[-20:]
# Out:
# [' Romance',
#  ' Mystery',
#  ' Mystery',
#  ' Romance',
#  ' Family',
#  ' Thriller',
#  ' Thriller',
#  ' Thriller',
#  ' Mystery',
#  ' Family',
#  ' Musical',
#  ' Sci-Fi',
#  ' Family',
#  ' Family',
#  ' Thriller',
#  ' Comedy',
#  ' History',
#  ' Drama',
#  ' Drama',
#  ' Drama']

# %%
allGenre[:13]
# Out:
# ['Drama',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Documentary',
#  'Horror',
#  'Action',
#  'Drama',
#  'Horror',
#  'Horror']

# %%
# prompt: delete all None from the allGenre list

allGenre = [x for x in allGenre if x is not None]

# %%
plt.hist(allGenre,bins = len(set(allGenre)))
plt.xticks(rotation='vertical');

# %% [markdown]
# # Quiz15 หาพระเอก-นางเอก ที่มักจะแสดงคู่กัน ด้วย Histogram (พระเอก actor1, นางเอก actor2)

# %% [markdown]
# #### การแสดงผลภาษาไทย

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
x = np.arange(len(compare1))
width = 0.35
fig,ax = plt.subplots()
rects1 = ax.bar(x - width/2, compare1['Type'], width, label='มกราคม')
rects2 = ax.bar(x + width/2, compare2['Type'], width, label='กุมภาพันธ์')

ax.set_ylabel('count')
ax.set_title('Number of Cases open by different ethnicity')
ax.set_xticks(x)
ax.set_xticklabels(compare1['Officer-defined ethnicity'])
ax.legend()

plt.show()

# %% [markdown]
# ## Tree map

# %%
# !pip install squarify

# %%
# prompt: plot treemap compare number of cases based on object of search

import pandas as pd
import matplotlib.pyplot as plt
import squarify
import numpy as np

# Assuming 'df1' contains the data for the first month
object_counts = df1['Object of search'].value_counts()
fig, ax = plt.subplots(figsize=(12, 7))
# Define a list of blue colors based on the number of categories
colors = plt.cm.Blues(np.linspace(1, 0.4, len(object_counts)))

# Create the treemap
squarify.plot(sizes=object_counts.values, label=object_counts.index, alpha=.8, color=colors)
plt.axis('off')
plt.title('Number of Cases by Object of Search (Jan)')
plt.show()

# %%
object_counts.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Object of search'>

# %%
# prompt: plot treemap of the genre

import pandas as pd
import matplotlib.pyplot as plt
# !pip install squarify

import squarify

# Assuming 'allGenre' contains the list of genres you want to plot
genre_counts = pd.Series(allGenre).value_counts()

# Create the treemap
squarify.plot(sizes=genre_counts.values, label=genre_counts.index, alpha=.8 )
plt.axis('off')
plt.show()

# %% [markdown]
# ## Radar Chart

# %%
import numpy as np
import pandas as pd  #import pandas มาเพราะข้อมูลจะเกี่ยวกับตาราง
import matplotlib.pyplot as plt
from math import pi #import math มาเนื่องจากเกี่ยวกับวงกลมนำมาใช้เพื่อดึงค่าพาย

# %%
data = {'client_id' : ['c1' , 'c2' , 'c3' , 'c4'],
         'cheese' : [2,5,4,3],
         'beer' : [2,1,3,5],
         'chicken' : [5,3,3,4],
        'bread' : [4,3,2,1],
       'coffee' : [2,3,5,3]}
df = pd.DataFrame.from_dict(data)
df
# Out:
#   client_id  cheese  beer  chicken  bread  coffee
# 0        c1       2     2        5      4       2
# 1        c2       5     1        3      3       3
# 2        c3       4     3        3      2       5
# 3        c4       3     5        4      1       3

# %%
categories = list(df.columns[1:])
categories
# Out:
# ['cheese', 'beer', 'chicken', 'bread', 'coffee']

# %%
values = df.iloc[:,1:].mean().values.flatten().tolist()
values += values[:1] # repeat the first value to close the circular graph
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5),
                       subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)

plt.ylim(0, 5)
ax.set_rlabel_position(30)

ax.plot(angles, values, linewidth=1, linestyle='solid' , color = '#ea3033') #เส้นกราฟ
ax.fill(angles, values, 'lightpink', alpha=0.5) #พื้นที่

# %%
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)

plt.ylim(0, 5)
ax.set_rlabel_position(30)

# part 1
val_c1 = df.loc[0].drop('client_id').values.flatten().tolist()
val_c1 += val_c1[:1]
ax.plot(angles, val_c1, linewidth=1,
        linestyle='solid', label='Client c1')
ax.fill(angles, val_c1, 'skyblue', alpha=0.4)

# part 2
val_c2=df.loc[1].drop('client_id').values.flatten().tolist()
val_c2 += val_c2[:1]
ax.plot(angles, val_c2, linewidth=1,
        linestyle='solid', label='Client c2')
ax.fill(angles, val_c2, 'lightpink', alpha=0.4)

plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# %%
df1.head(2)
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude Gender Age range  \
# 0                 NaN  51.881481   -0.41311   Male     25-34
# 1                 NaN  52.132059   -0.29660   Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 1  White - English/Welsh/Scottish/Northern Irish/...
#
#   Officer-defined ethnicity  \
# 0                     Other
# 1                     White
#
#                                          Legislation   Object of search  \
# 0  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 1  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
#
#                         Outcome Outcome linked to object of search  \
# ...

# %%
df1['Object of search'].value_counts()
# Out:
# Object of search
# Controlled drugs            286
# Article for use in theft     46
# Offensive weapons            37
# Stolen goods                 14
# Firearms                      4
# Name: count, dtype: int64

# %% [markdown]
# #quiz 14

# %%
data1 = pd.read_csv(path1)
data2 = pd.read_csv(path2)
df3 = pd.read_csv(path3)
df4 = pd.read_csv(path4)

# %%
# Group data by 'Object of search' for each month
object_of_search_month1 = data1.groupby('Object of search')['Type'].count().reset_index()
object_of_search_month2 = data2.groupby('Object of search')['Type'].count().reset_index()

# Merge the dataframes for easier plotting
merged_object_of_search = pd.merge(object_of_search_month1, object_of_search_month2, on='Object of search', suffixes=('_Jan', '_Feb'), how='outer')

# Fill NaN values with 0 if an object of search doesn't exist in a month
merged_object_of_search = merged_object_of_search.fillna(0)

# Prepare data for scaling by melting the DataFrame
melted_data = merged_object_of_search.melt(id_vars='Object of search', value_vars=['Type_Jan', 'Type_Feb'], var_name='Month', value_name='Count')

# Apply Min-Max Scaling to the combined data
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
melted_data['Count'] = scaler.fit_transform(melted_data[['Count']])

# Pivot the data back to the original format
scaled_merged_object_of_search = melted_data.pivot(index='Object of search', columns='Month', values='Count').reset_index()

# Rename columns back
scaled_merged_object_of_search.columns.name = None
scaled_merged_object_of_search = scaled_merged_object_of_search.rename(columns={'Type_Jan': 'Type_Jan', 'Type_Feb': 'Type_Feb'})


merged_object_of_search = scaled_merged_object_of_search
merged_object_of_search
# Out:
#                       Object of search  Type_Feb  Type_Jan
# 0             Article for use in theft  0.069930  0.160839
# 1  Articles for use in criminal damage  0.006993  0.000000
# 2                     Controlled drugs  0.765734  1.000000
# 3                             Firearms  0.003497  0.013986
# 4                    Offensive weapons  0.118881  0.129371
# 5                         Stolen goods  0.038462  0.048951

# %%
merged_object_of_search = merged_object_of_search[merged_object_of_search['Object of search'] != 'Articles for use in criminal damage']
merged_object_of_search
# Out:
#            Object of search  Type_Feb  Type_Jan
# 0  Article for use in theft  0.069930  0.160839
# 2          Controlled drugs  0.765734  1.000000
# 3                  Firearms  0.003497  0.013986
# 4         Offensive weapons  0.118881  0.129371
# 5              Stolen goods  0.038462  0.048951

# %%
categories = merged_object_of_search['Object of search'].tolist()
values_jan = merged_object_of_search['Type_Jan'].tolist()
values_feb = merged_object_of_search['Type_Feb'].tolist()

# Repeat the first value to close the circular graph
values_jan += values_jan[:1]
values_feb += values_feb[:1]

angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6, 6),
                       subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories, color='grey', size=12)
ax.set_rlabel_position(0) # Adjust position of radial labels


# Plot January data
ax.plot(angles, values_jan, linewidth=1, linestyle='solid', label='มกราคม', color='skyblue')
ax.fill(angles, values_jan, 'skyblue', alpha=0.4)

# Plot February data
ax.plot(angles, values_feb, linewidth=1, linestyle='solid', label='กุมภาพันธ์', color='lightpink')
ax.fill(angles, values_feb, 'lightpink', alpha=0.4)

plt.title('เปรียบเทียบจำนวน Object of search ในเดือน มกราคม และ กุมภาพันธ์ (Min-Max Scaled)', size=12, color='blue', y=1.1) # Add title and update title

plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

plt.show()
