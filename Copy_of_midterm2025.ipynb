# %% [markdown]
# <a href="https://colab.research.google.com/github/znumunz/dataviz2025/blob/main/Copy_of_midterm2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ผู้ร้ายชื่อ Joe Germuska
# # ID ผู้บงการ ผู้บงการ id 918773

# %% [markdown]
# ให้สืบหาฆาตรกร (10 คะแนน) และ ผู้บงการ (5 คะแนน) ในคดี ฆาตรกรรม (murder) ที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง Pandas City โดยเริ่มจากการตรวจสอบ ข้อมูลคดีในไฟล์ crime_scene_report.csv

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Middataviz'

# %%
cri_rp = pd.read_csv(path + '/crime_scene_report.csv')
cri_rp
# Out:
#           date     type                                        description  \
# 0     20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1     20180115   murder                  Life? Dont talk to me about life.
# 2     20180115   murder  Mama, I killed a man, put a gun against his he...
# 3     20180215   murder                         REDACTED REDACTED REDACTED
# 4     20180215   murder  Someone killed the guard! He took an arrow to ...
# ...        ...      ...                                                ...
# 1223  20180430  bribery                                                 \n
# 1224  20180430    fraud                  ‘Why not?’ said the March Hare.\n
# 1225  20180430  assault                                                 \n
# 1226  20180501  assault  be NO mistake about it: it was neither more no...
# 1227  20180115   murder  Security footage shows that there were 2 witne...
#
#               city
# 0              NYC
# 1           Albany
# ...

# %%
murder_pandascity_20180115 = cri_rp[(cri_rp['type']=='murder') & (cri_rp['date']==20180115) & (cri_rp['city']=='Pandas City')]

# %%
# Out:
# 1227    Security footage shows that there were 2 witne...
# Name: description, dtype: object

# %%
pd.set_option('display.max_colwidth', None)
display(murder_pandascity_20180115['description'])
# Out:
# 1227    Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".
# Name: description, dtype: object

# %% [markdown]
# **ภาพจากกล้องวงจรปิดแสดงให้เห็นว่ามีพยาน 2 คน พยานคนแรกอาศัยอยู่ที่บ้านหลังสุดท้ายบนถนน "Northwestern Dr" ส่วนพยานคนที่สองชื่อแอนนาเบล อาศัยอยู่ที่ไหนสักแห่งบนถนน "Franklin Ave"**

# %%
crime = pd.read_csv(path + '/crime_scene_report.csv')
driven_license = pd.read_csv(path + '/drivers_license.csv')
facebook_event_checkin = pd.read_csv(path + '/facebook_event_checkin.csv')
income = pd.read_csv(path + '/income.csv')
get_fit_now_check_in = pd.read_csv(path + '/get_fit_now_check_in.csv')
get_fit_now_member = pd.read_csv(path + '/get_fit_now_member.csv')
interview = pd.read_csv(path + '/interview.csv')
person = pd.read_csv(path + '/person.csv')

# %%
print(crime.columns)
print(driven_license.columns)
print(facebook_event_checkin.columns)
print(get_fit_now_check_in.columns)
print(get_fit_now_member.columns)
print(income.columns)
print(interview.columns)
print(person.columns)
# Out:
# Index(['date', 'type', 'description', 'city'], dtype='object')
# Index(['id', 'age', 'height', 'eye_color', 'hair_color', 'gender',
#        'plate_number', 'car_make', 'car_model'],
#       dtype='object')
# Index(['person_id', 'event_id', 'event_name', 'date'], dtype='object')
# Index(['membership_id', 'check_in_date', 'check_in_time', 'check_out_time'], dtype='object')
# Index(['id', 'person_id', 'name', 'membership_start_date',
#        'membership_status'],
#       dtype='object')
# Index(['ssn', 'annual_income'], dtype='object')
# Index(['person_id', 'transcript'], dtype='object')
# Index(['id', 'name', 'license_id', 'address_number', 'address_street_name',
#        'ssn'],
#       dtype='object')

# %%
person_Dr = person[person['address_street_name']=='Northwestern Dr'].head()

# %%
address_number_max = person_Dr['address_number'].max()
address_number_max
# Out:
# 4919

# %% [markdown]
# ## หาคนข้อมูลพยานคนแรก

# %%
person[person['address_number']==address_number_max]
# Out:
#         id            name  license_id  address_number address_street_name  \
# 499  14887  Morty Schapiro      118009            4919     Northwestern Dr
#
#            ssn
# 499  111564949

# %% [markdown]
# ## ถอดเสียงการสัมภาษณ์

# %%
interview[interview['person_id']==14887]
# Out:
#       person_id  \
# 4988      14887
#
#                                                                                                                                                                                                                            transcript
# 4988  I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".

# %% [markdown]
# ## ผมได้ยินเสียงปืน แล้วก็เห็นผู้ชายคนหนึ่งวิ่งออกมา เขามีกระเป๋าที่เขียนว่า "Get Fit Now Gym" หมายเลขสมาชิกบนกระเป๋าเริ่มต้นด้วย "48Z" ซึ่งมีเฉพาะสมาชิกระดับ Gold เท่านั้นที่ได้กระเป๋าแบบนี้ ผู้ชายคนนั้นขึ้นรถที่มีป้ายทะเบียนซึ่งมีตัวอักษร "H42W" อยู่ด้วย

# %% [markdown]
# #ผู้ต้องสงสัย

# %%
get_fit_now_member[
    (get_fit_now_member['membership_status'] == 'gold') &
    (get_fit_now_member['id'].str.startswith('48Z'))
]
# Out:
#         id  person_id           name  membership_start_date membership_status
# 181  48Z7A      28819   Joe Germuska               20160305              gold
# 182  48Z55      67318  Jeremy Bowers               20160101              gold

# %% [markdown]
# ## ผู้ชายคนนั้นขึ้นรถที่มีป้ายทะเบียนซึ่งมีตัวอักษร "H42W" อยู่ด้วย

# %%
drivers[drivers['plate_number'].str.startswith('H42W')]
# Out:
#          id  age  height eye_color hair_color  gender plate_number car_make  \
# 915  183779   21      65      blue     blonde  female       H42W0X   Toyota
#
#     car_model
# 915     Prius

# %%
person[person['id']==183779]
# Out:
# Empty DataFrame
# Columns: [id, name, license_id, address_number, address_street_name, ssn]
# Index: []

# %%
interview[interview['person_id']==183779]
# Out:
# Empty DataFrame
# Columns: [person_id, transcript]
# Index: []

# %% [markdown]
# ## หาคนข้อมูลพยานคนที่สอง ชื่อแอนนาเบล อาศัยอยู่ที่ไหนสักแห่งบนถนน "Franklin Ave"

# %%
Franklin = person[(person['address_street_name']=='Franklin Ave')&(person['name'].str.startswith('Annabel'))]
Franklin.head()
# Out:
#         id            name  license_id  address_number address_street_name  \
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn
# 665  318771143

# %%
interview = pd.read_csv(path + '/interview.csv')

# %%
interview[interview['person_id']==16371]
# Out:
#       person_id  \
# 4989      16371
#
#                                                                                                                  transcript
# 4989  I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.

# %% [markdown]
# ## ฉันเห็นเหตุการณ์ฆาตกรรมเกิดขึ้น และฉันจำคนร้ายได้จากยิมของฉัน ตอนที่ฉันกำลังออกกำลังกายในสัปดาห์ที่แล้ว วันที่ 9 มกราคม

# %% [markdown]
# # ผู้บงการ id 918773
# ฉันได้รับการว่าจ้างจากผู้หญิงคนหนึ่งซึ่งมีเงินมาก ฉันไม่ทราบชื่อของเธอ แต่รู้ว่าเธอสูงประมาณ 5 ฟุต 5 นิ้ว (65 นิ้ว) หรือ 5 ฟุต 7 นิ้ว (67 นิ้ว) เธอมีผมสีแดง และเธอขับรถ Tesla Model S ฉันทราบว่าเธอเข้าร่วมคอนเสิร์ต SQL Symphony ทั้งหมด 3 ครั้งในเดือนธันวาคม ปี 2017

# %%
drivers[
    (drivers['hair_color'] == 'red') &
    (drivers['car_make'] == 'Tesla') &
    (drivers['height'].isin([65, 67]))
]
# Out:
#           id  age  height eye_color hair_color  gender plate_number car_make  \
# 9078  918773   48      65     black        red  female       917UU3    Tesla
#
#      car_model
# 9078   Model S

# %%
person[person['id']==918773]
# Out:
# Empty DataFrame
# Columns: [id, name, license_id, address_number, address_street_name, ssn]
# Index: []

# %% [markdown]
# #หาคนร้าย

# %%
members_48Z = get_fit_now_member[get_fit_now_member['id'].str.startswith('48Z')]
merged_check_ins = pd.merge(members_48Z, get_fit_now_check_in, left_on='id', right_on='membership_id', how='left')
display(merged_check_ins)
# Out:
#       id  person_id           name  membership_start_date membership_status  \
# 0  48Z38      49550  Tomas Baisley               20170203            silver
# 1  48Z38      49550  Tomas Baisley               20170203            silver
# 2  48Z38      49550  Tomas Baisley               20170203            silver
# 3  48Z38      49550  Tomas Baisley               20170203            silver
# 4  48Z38      49550  Tomas Baisley               20170203            silver
# 5  48Z7A      28819   Joe Germuska               20160305              gold
# 6  48Z55      67318  Jeremy Bowers               20160101              gold
#
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         48Z38       20170611            813            1122
# 1         48Z38       20171212           1150            1153
# 2         48Z38       20170820            919             921
# 3         48Z38       20180314            315            1150
# ...
